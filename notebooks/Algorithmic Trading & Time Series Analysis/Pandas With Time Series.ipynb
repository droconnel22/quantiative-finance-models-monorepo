# %% [markdown]
# ## Time Series Basics
#
# ![screenshot_1](./images/Image_1.png)

# %%
import pandas as pd
import numpy as np
import pandas_datareader.data as web
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from datetime import datetime

# %%
# zKYsMEfvyGrpJ-bk5J2V
# https://docs.quandl.com/docs/python
import quandl

# %%
quandl.ApiConfig.api_key = 'zKYsMEfvyGrpJ-bk5J2V'

# %%
my_year = 2017
my_month = 1
my_day = 2
my_hour = 16
my_min = 30
my_sec = 15

# %%
# shift + tab
my_date = datetime(my_year, my_month, my_day)
my_date
# Out:
# datetime.datetime(2017, 1, 2, 0, 0)

# %%
my_date_time = datetime(my_year, my_month, my_day, my_hour, my_min, my_sec)
my_date_time
# Out:
# datetime.datetime(2017, 1, 2, 16, 30, 15)

# %%
type(my_date), type(my_date_time)
# Out:
# (datetime.datetime, datetime.datetime)

# %%
my_date_time.month
# Out:
# 1

# %%
first_two = [datetime(2016,1,1),datetime(2016,1,2)]

# %%
first_two
# Out:
# [datetime.datetime(2016, 1, 1, 0, 0), datetime.datetime(2016, 1, 2, 0, 0)]

# %%
type(first_two)
# Out:
# list

# %%
dt_ind = pd.DatetimeIndex(first_two)
dt_ind
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02'], dtype='datetime64[ns]', freq=None)

# %%
np.random.seed(1000)

# %%
data = np.random.randn(2,2)
data
# Out:
# array([[-0.8044583 ,  0.32093155],
#        [-0.02548288,  0.64432383]])

# %%
cols = ['a','b']

# %%
df = pd.DataFrame(data, dt_ind, cols)
df
# Out:
#                    a         b
# 2016-01-01 -0.804458  0.320932
# 2016-01-02 -0.025483  0.644324

# %%
# Index location of latest date"
df.index.argmax()
# Out:
# 1

# %%
# Index value of max value
df.index.max()
# Out:
# Timestamp('2016-01-02 00:00:00')

# %%
df.index.argmin()
# Out:
# 0

# %%
df.index.min()
# Out:
# Timestamp('2016-01-01 00:00:00')

# %%
# Frequency sampling tools!

# %%
# %env QUANDL_API_KEY=zKYsMEfvyGrpJ-bk5J2V
# Out:
# env: QUANDL_API_KEY=zKYsMEfvyGrpJ-bk5J2V

# %%
wmt_df = pd.read_csv("./data/walmart_stock.csv")
#

# %%
wmt_df.head()
# Out:
#          Date       Open       High        Low      Close    Volume  Adj Close
# 0  2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 1  2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2  2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 3  2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 4  2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215

# %%
wmt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   object
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Volume     1258 non-null   int64
#  6   Adj Close  1258 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB

# %%
  wmt_df['Date'] = pd.to_datetime(wmt_df['Date'])

# %%
wmt_df.head()
# Out:
#         Date       Open       High        Low      Close    Volume  Adj Close
# 0 2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 1 2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2 2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 3 2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 4 2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215

# %%
wmt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   datetime64[ns]
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Volume     1258 non-null   int64
#  6   Adj Close  1258 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 68.9 KB

# %%
wmt_df.set_index('Date',inplace=True)

# %%
wmt_df.head()
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215

# %%
wmt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2012-01-03 to 2016-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1258 non-null   float64
#  1   High       1258 non-null   float64
#  2   Low        1258 non-null   float64
#  3   Close      1258 non-null   float64
#  4   Volume     1258 non-null   int64
#  5   Adj Close  1258 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 68.8 KB

# %%
# Smart way!
wmt_df_2 = pd.read_csv("./data/walmart_stock.csv", index_col='Date', parse_dates=True)

# %%
wmt_df_2.head()
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215

# %%
wmt_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2012-01-03 to 2016-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1258 non-null   float64
#  1   High       1258 non-null   float64
#  2   Low        1258 non-null   float64
#  3   Close      1258 non-null   float64
#  4   Volume     1258 non-null   int64
#  5   Adj Close  1258 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 68.8 KB

# %% [markdown]
# ### Time Resampling
#
# |Alias  |   Description |
# | ------| --------------|
# |B      | business day frequency|
# |C      |  custom business day frequency
# |D      |  calendar day frequency
# |W      |  weekly frequency
# |M      |  month end frequency
# |SM     |  semi-month end frequency (15th and end of month)
# |BM     |  business month end frequency
# |CBM    |  custom business month end frequency
# |MS     |  month start frequency
# |SMS    |  semi-month start frequency (1st and 15th)
# |BMS    |  business month start frequency
# |CBMS   |  custom business month start frequency
# |Q      |  quarter end frequency
# |BQ     |  business quarter end frequency
# |QS     |  quarter start frequency
# |BQS    |  business quarter start frequency
# |A, Y   |  year end frequency
# |BA, BY |  business year end frequency
# |AS, YS |  year start frequency
# |BAS, BY|S business year start frequency
# |BH     |  business hour frequency
# |H      |  hourly frequency
# |T, min |  minutely frequency
# |S      |  secondly frequency
# |L, ms  |  milliseconds
# |U, us  |  microseconds
# |N      |  nanoseconds

# %%
wmt_df.resample(rule='A').mean()
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 2012-12-31  67.158680  67.602120  66.786520  67.215120  9.239015e+06
# 2013-12-31  75.264048  75.729405  74.843055  75.320516  6.951496e+06
# 2014-12-31  77.274524  77.740040  76.864405  77.327381  6.515612e+06
# 2015-12-31  72.569405  73.064167  72.034802  72.491111  9.040769e+06
# 2016-12-31  69.481349  70.019643  69.023492  69.547063  9.371645e+06
#
#             Adj Close
# Date
# 2012-12-31  59.389349
# 2013-12-31  68.147179
# 2014-12-31  71.709712
# 2015-12-31  68.831426
# 2016-12-31  68.054229

# %%
wmt_df.resample(rule='Q').mean()
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 2012-03-31  60.462903  60.807258  60.160484  60.519516  8.850221e+06
# 2012-06-30  62.888889  63.400159  62.592222  63.057143  1.155795e+07
# 2012-09-30  73.081587  73.549682  72.717619  73.174921  7.871587e+06
# 2012-12-31  72.174678  72.623226  71.647741  72.079839  8.660958e+06
# 2013-03-31  70.898834  71.393000  70.552666  71.026000  8.482003e+06
# 2013-06-30  76.873906  77.417813  76.413281  76.885781  7.656086e+06
# 2013-09-30  75.637969  76.030469  75.213594  75.629063  5.796625e+06
# 2013-12-31  77.372656  77.805313  76.924531  77.472813  5.966927e+06
# 2014-03-31  75.339344  75.802787  74.863278  75.337213  7.050402e+06
# 2014-06-30  77.036508  77.391111  76.689524  77.066508  6.048765e+06
# 2014-09-30  75.674843  76.062501  75.375938  75.748593  5.550031e+06
# 2014-12-31  80.952969  81.607500  80.432344  81.059844  7.431025e+06
# ...

# %%
wmt_df.resample(rule='BQ').mean()
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 2012-03-30  60.462903  60.807258  60.160484  60.519516  8.850221e+06
# 2012-06-29  62.888889  63.400159  62.592222  63.057143  1.155795e+07
# 2012-09-28  73.081587  73.549682  72.717619  73.174921  7.871587e+06
# 2012-12-31  72.174678  72.623226  71.647741  72.079839  8.660958e+06
# 2013-03-29  70.898834  71.393000  70.552666  71.026000  8.482003e+06
# 2013-06-28  76.873906  77.417813  76.413281  76.885781  7.656086e+06
# 2013-09-30  75.637969  76.030469  75.213594  75.629063  5.796625e+06
# 2013-12-31  77.372656  77.805313  76.924531  77.472813  5.966927e+06
# 2014-03-31  75.339344  75.802787  74.863278  75.337213  7.050402e+06
# 2016-12-31  69.940002  70.000000  69.260002  69.309998   4875700  68.804087
# 2016-12-31  69.209999  69.519997  69.120003  69.260002   4298400  68.754456
# 2016-12-31  69.120003  69.430000  68.830002  69.120003   6889500  68.615479
#
# [1258 rows x 6 columns]

# %% [markdown]
# ### Pandas Rolling & Expanding

# %%
wmt_df.head()
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215

# %%
wmt_df['Open'].plot(figsize=(16,8));

# %%
# rolling mean to week
wmt_df.rolling(7).mean().head(20)
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 2012-01-03        NaN        NaN        NaN        NaN           NaN
# 2012-01-04        NaN        NaN        NaN        NaN           NaN
# 2012-01-05        NaN        NaN        NaN        NaN           NaN
# 2012-01-06        NaN        NaN        NaN        NaN           NaN
# 2012-01-09        NaN        NaN        NaN        NaN           NaN
# 2012-01-10        NaN        NaN        NaN        NaN           NaN
# 2012-01-11  59.495714  59.895714  59.074285  59.440000  9.007414e+06
# 2012-01-12  59.469999  59.744285  59.007143  59.321429  8.231357e+06
# 2012-01-13  59.322857  59.638571  58.941428  59.297143  7.965071e+06
# 2012-01-17  59.397143  59.708571  59.105714  59.358572  7.355329e+06
# 2012-01-18  59.450000  59.791428  59.217143  59.502857  7.047043e+06
# 2012-01-19  59.578572  59.960000  59.335715  59.707143  7.412086e+06
# ...

# %%
wmt_df['Open'].plot()
wmt_df.rolling(window=20).mean()['Close'].plot()
wmt_df.rolling(window=50).mean()['Close'].plot()
wmt_df.rolling(window=100).mean()['Close'].plot()
wmt_df.rolling(window=200).mean()['Close'].plot(figsize=(16,10));

# %%
wmt_df['Close 30 Day MA'] = wmt_df['Close'].rolling(window=30).mean()

# %%
wmt_df['Close 200 Day MA'] = wmt_df['Close'].rolling(window=200).mean()

# %%
wmt_df[['Close','Close 30 Day MA','Close 200 Day MA']].plot(figsize=(16,10))

# %%
wmt_df['Close'].expanding(min_periods=1).mean().plot(figsize=(16,10))

# %% [markdown]
# ### Bollinger Bands

# %%
# Close Price 20 Day MA
wmt_df['Close 20 MA'] = wmt_df['Close'].rolling(window=20).mean()
# Upper Band = 20 Day MA + 2 * Std Dev(20 Days)
wmt_df['Upper'] = wmt_df['Close 20 MA'] + 2.5 * (wmt_df['Close'].rolling(20).std())
# Lower Band = 20 Day MA - 2 * Std Dev (20 Days)
wmt_df['Lower'] = wmt_df['Close 20 MA'] - 2.5 * (wmt_df['Close'].rolling(20).std())
# Plot
wmt_df[['Close','Close 20 MA','Upper','Lower']].tail(200).plot(figsize=(16,10));
