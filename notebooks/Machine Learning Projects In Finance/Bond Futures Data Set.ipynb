# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import quandl
import datetime

# %%
bond_futures = quandl.get("CHRIS/CME_US1", authtoken="zKYsMEfvyGrpJ-bk5J2V")

# %%
bond_futures.head()
# Out:
#                Open     High      Low     Last  Change   Settle  Volume  \
# Date
# 1977-08-22  102.250  102.469  102.219  102.375     NaN  102.375   341.0
# 1977-08-23  102.375  102.781  102.375  102.781     NaN  102.781   145.0
# 1977-08-24  102.781  102.781  102.625  102.656     NaN  102.656   207.0
# 1977-08-25  102.719  103.188  102.688  103.094     NaN  103.094   158.0
# 1977-08-26  103.031  103.719  102.969  103.062     NaN  103.062   168.0
#
#             Previous Day Open Interest
# Date
# 1977-08-22                       148.0
# 1977-08-23                       178.0
# 1977-08-24                       325.0
# 1977-08-25                       383.0
# 1977-08-26                       426.0

# %%
bond_futures['Last'].plot(figsize=(16,6));

# %%
bond_futures['Normalized Last'] = ( bond_futures['Last'] / bond_futures['Last'].iloc[0])

# %%
bond_futures['Normalized Last'].plot(figsize=(16,6));
